# %%
from DataCollector import DataCollectorv2
from Dataset import DatasetHPs
from NNModel import NNModelHPs
from covit import CovitProject

# %%
dc = DataCollectorv2()
# Out:
# Building Data frame
# Done building Data frame
# Building remote dicts
# Done building remote dicts
# Building local dicts
# Done building local dicts

# %%
covit375 = CovitProject(project_name="375Lins",
                        data_collector=dc)

# %%
nnmodel_hps = NNModelHPs(
    encoder_repeats = 2,
    classes = len(covit375.dataset.getLineages()),
    d_model = covit375.dataset.hps.frag_len,
    d_val = 64,
    d_key = 64,
    d_ff = 1024,
    heads = 16,
    dropout_rate = 0.1
)

covit375.addNNModel("nn3",
                    nnmodel_hps)

# %%
covit375.train(name='nn3',
               epochs=10,
               batch_size=256)
# Out:
# Epoch 1/10
#   6/909 [..............................] - ETA: 9:51 - loss: 362.3977 - top1_accuracy: 0.0033 - top2_accuracy: 0.0052 - top5_accuracy: 0.0163

# %%
covit375.evaluate(name="nn3",batch_size=192)
# Out:
# 304/304 [==============================] - 71s 228ms/step - loss: 4.5044 - top1_accuracy: 0.4052 - top2_accuracy: 0.4956 - top5_accuracy: 0.6092
# [4.5044450759887695,
#  0.4052288830280304,
#  0.4955940246582031,
#  0.6091548204421997]

# %%
covit375.getResults("nn3").getPerf()
# Out:
# {'loss': [8.26511287689209,
#   4.382845401763916,
#   4.062258720397949,
#   3.976710796356201,
#   3.876039505004883,
#   3.8240349292755127,
#   3.7748382091522217,
#   3.7274341583251953,
#   3.6964592933654785,
#   3.6747474670410156,
#   3.63596510887146,
#   3.5877888202667236,
#   3.530221939086914,
#   3.4076294898986816,
#   3.1879944801330566,
#   3.090498924255371,
#   2.923126697540283,
#   2.762315511703491,
#   2.536809206008911,
#   2.4507927894592285,
#   2.3869073390960693,
#   2.343299150466919,
#   2.303218364715576,
#   2.2742903232574463,
#   2.2482552528381348,
#   2.415172576904297,
#   2.3732540607452393,
#   2.3475582599639893,
#   2.337246894836426,
#   2.311746597290039,
#   2.30021595954895,
#   2.2795755863189697,
#   2.273981809616089,
#   2.2674760818481445,
#   2.259101152420044,
#   2.254483222961426,
#   2.244814157485962,
#   2.2446441650390625,
#   2.2376549243927,
#   2.2312631607055664],
#  'top1_accuracy': [0.04381531849503517,
#   0.0863543376326561,
#   0.1073552668094635,
#   0.11940920352935791,
#   0.13561004400253296,
#   0.14119654893875122,
#   0.14720846712589264,
#   0.15551085770130157,
#   0.15927530825138092,
#   0.16304834187030792,
#   0.172141432762146,
#   0.1840621531009674,
#   0.1983335018157959,
#   0.2254623919725418,
#   0.26082921028137207,
#   0.28314509987831116,
#   0.32185524702072144,
#   0.36429542303085327,
#   0.4126228988170624,
#   0.4310755431652069,
#   0.4456304907798767,
#   0.4580840766429901,
#   0.4662919342517853,
